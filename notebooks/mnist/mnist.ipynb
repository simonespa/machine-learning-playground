# %% [markdown]
# # MNIST

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, parser='auto')

# %%
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
import numpy as np

X, y = mnist["data"], mnist["target"].astype(np.uint8)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

number_five = np.array(X.loc[0])
number_five_image = number_five.reshape(28, 28)

plt.imshow(number_five_image, cmap = mpl.cm.binary, interpolation="nearest")
plt.axis("off")
plt.show()

# %%
y[0]
# Out:
# np.uint8(5)

# %%
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]

# %%
y_train_5 = (y_train == 5) # True for all 5s, False for all other digits.
y_test_5 = (y_test == 5)

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train_5)
# Out:
# SGDClassifier(random_state=42)

# %%
sgd_clf.predict([number_five])
# Out:
# /Users/spaccs01/workspace/playground/machine-learning-playground/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   warnings.warn(
# array([ True])
