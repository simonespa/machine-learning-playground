# %% [markdown]
# # Image visualistion

# %%
import IPython
from PIL import Image
import pathlib

# %%
image_path = pathlib.Path('../images/roses.jpg')

# %%
IPython.display.display(Image.open(image_path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>

# %%
IPython.display.Image(filename=image_path)
